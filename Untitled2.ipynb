# %% [markdown]
# <a href="https://colab.research.google.com/github/nichakornchaisuwan/DWDM21/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/dataviz_2021_data'

# %%
data = os.path.join(path,'โรงงาน.csv') 
data_edm = pd.read_csv(data)

# %%
data_edm
# Out:
#       ลำดับ    เลขทะเบียนเดิม           FID  ...  เงินทุนรวม คนงานรวม   แรงม้า
# 0         1  จ3-58(1)-18/61รย  2.020000e+13  ...   5500000.0       10   249.10
# 1         2   จ3-40(2)-4/48รย  2.020000e+13  ...  51000000.0       38   291.32
# 2         3  จ3-53(5)-30/49รย  2.020000e+13  ...   2050000.0        8   244.00
# 3         4   จ3-48(1)-2/49รย  2.020000e+13  ...  25000000.0       34   105.20
# 4         5    3-53(8)-1/48รย  1.020000e+13  ...  53000000.0       21  1957.30
# ...     ...               ...           ...  ...         ...      ...      ...
# 7577   7578     3-3(1)-2/19ชบ  1.020000e+13  ...  21692393.0       33  1417.50
# 7578   7579    3-50(4)-2/38ชบ  1.020000e+13  ...  23500000.0       15  1769.04
# 7579   7580     3-3(1)-1/26ชบ  1.020000e+13  ...  10950000.0        5  5353.00
# 7580   7581    3-15(1)-1/29ชบ  1.020000e+13  ...    800000.0        7   275.55
# 7581   7582      จ3-51-1/41ชบ  2.020000e+13  ...   3800000.0       21   214.54
#
# ...

# %%
data_edm.isnull().any() # ตรวจสอบค่า missing
# Out:
# ลำดับ             False
# เลขทะเบียนเดิม    False
# FID               False
# ชื่อโรงงาน        False
# ประกอบกิจการ       True
# เลขที่             True
# หมู่               True
# ซอย                True
# ถนน                True
# ตำบล              False
# อำเภอ             False
# จังหวัด           False
# ไปรษณีย์          False
# โทรศัพท์           True
# เงินทุนรวม        False
# คนงานรวม          False
# แรงม้า            False
# dtype: bool

# %%
data_edm = data_edm.fillna(value={'ประกอบกิจการ':'ไม่ระบุ','เลขที่':'ไม่ระบุ','หมู่':'ไม่ระบุ','ซอย':'ไม่ระบุ','ถนน':'ไม่ระบุ','โทรศัพท์':'ไม่ระบุ'})
data_edm
# Out:
#       ลำดับ    เลขทะเบียนเดิม           FID  ...  เงินทุนรวม คนงานรวม   แรงม้า
# 0         1  จ3-58(1)-18/61รย  2.020000e+13  ...   5500000.0       10   249.10
# 1         2   จ3-40(2)-4/48รย  2.020000e+13  ...  51000000.0       38   291.32
# 2         3  จ3-53(5)-30/49รย  2.020000e+13  ...   2050000.0        8   244.00
# 3         4   จ3-48(1)-2/49รย  2.020000e+13  ...  25000000.0       34   105.20
# 4         5    3-53(8)-1/48รย  1.020000e+13  ...  53000000.0       21  1957.30
# ...     ...               ...           ...  ...         ...      ...      ...
# 7577   7578     3-3(1)-2/19ชบ  1.020000e+13  ...  21692393.0       33  1417.50
# 7578   7579    3-50(4)-2/38ชบ  1.020000e+13  ...  23500000.0       15  1769.04
# 7579   7580     3-3(1)-1/26ชบ  1.020000e+13  ...  10950000.0        5  5353.00
# 7580   7581    3-15(1)-1/29ชบ  1.020000e+13  ...    800000.0        7   275.55
# 7581   7582      จ3-51-1/41ชบ  2.020000e+13  ...   3800000.0       21   214.54
#
# ...

# %%
data_edm.isnull().sum()
# Out:
# ลำดับ             0
# เลขทะเบียนเดิม    0
# FID               0
# ชื่อโรงงาน        0
# ประกอบกิจการ      0
# เลขที่            0
# หมู่              0
# ซอย               0
# ถนน               0
# ตำบล              0
# อำเภอ             0
# จังหวัด           0
# ไปรษณีย์          0
# โทรศัพท์          0
# เงินทุนรวม        0
# คนงานรวม          0
# แรงม้า            0
# dtype: int64

# %%
data_chonburi = data_edm[data_edm['จังหวัด']=='ชลบุรี']
data_chonburi
# Out:
#       ลำดับ     เลขทะเบียนเดิม           FID  ...   เงินทุนรวม คนงานรวม   แรงม้า
# 41       42  จ3-64(12)-27/47ชบ  2.020000e+13  ...  125000000.0      135   240.00
# 42       43   จ3-95(1)-65/58ชบ  2.020000e+13  ...   17500000.0       11    59.30
# 43       44       ศ3-14-1/38ชบ  2.000000e+11  ...    7000000.0       12  1589.00
# 44       45   จ3-67(7)-13/49ชบ  2.020000e+13  ...   28660000.0       80   264.17
# 45       46    จ3-53(9)-8/52ชบ  2.020000e+13  ...    9900000.0       15    95.00
# ...     ...                ...           ...  ...          ...      ...      ...
# 7577   7578      3-3(1)-2/19ชบ  1.020000e+13  ...   21692393.0       33  1417.50
# 7578   7579     3-50(4)-2/38ชบ  1.020000e+13  ...   23500000.0       15  1769.04
# 7579   7580      3-3(1)-1/26ชบ  1.020000e+13  ...   10950000.0        5  5353.00
# 7580   7581     3-15(1)-1/29ชบ  1.020000e+13  ...     800000.0        7   275.55
# 7581   7582       จ3-51-1/41ชบ  2.020000e+13  ...    3800000.0       21   214.54
#
# ...

# %%
data_rayong = data_edm[data_edm['จังหวัด']=='ระยอง']
data_rayong
# Out:
#       ลำดับ       เลขทะเบียนเดิม  ...  คนงานรวม     แรงม้า
# 0         1     จ3-58(1)-18/61รย  ...        10     249.10
# 1         2      จ3-40(2)-4/48รย  ...        38     291.32
# 2         3     จ3-53(5)-30/49รย  ...         8     244.00
# 3         4      จ3-48(1)-2/49รย  ...        34     105.20
# 4         5       3-53(8)-1/48รย  ...        21    1957.30
# ...     ...                  ...  ...       ...        ...
# 7554   7555  น.88(2)-1/2553-นอต.  ...        41  260472.05
# 7555   7556  น.53(5)-2/2561-นอต.  ...         0    1865.00
# 7556   7557         จ3-39-7/62รย  ...        13     410.66
# 7557   7558    จ3-58(1)-135/63รย  ...        11     288.84
# 7558   7559      จ3-74(3)-2/64รย  ...        25     245.00
#
# [2217 rows x 17 columns]

# %%
data_chachoengsao = data_edm[data_edm['จังหวัด']=='ฉะเชิงเทรา']
data_chachoengsao
# Out:
#       ลำดับ       เลขทะเบียนเดิม           FID  ...   เงินทุนรวม คนงานรวม    แรงม้า
# 259     260          3-90-1/48ฉช  1.020000e+13  ...  900000000.0       14   3324.38
# 260     261  น.53(4)-2/2547-นวก.  8.210000e+13  ...          0.0      140  11823.00
# 261     262       3-64(6)-1/36ฉช  1.020000e+13  ...   47000000.0      240   7107.39
# 262     263       3-41(1)-1/35ฉช  1.020000e+13  ...   78500000.0       50   2110.96
# 351     352    จ3-95(1)-212/59ฉช  2.020000e+13  ...   49140000.0       79    283.65
# ...     ...                  ...           ...  ...          ...      ...       ...
# 7571   7572      จ3-77(2)-4/63ฉช  2.020000e+13  ...  194000000.0       20    408.00
# 7572   7573        3-105-56/48ฉช  1.020000e+13  ...    1400000.0       52     40.00
# 7573   7574          3-33-7/50ฉช  1.020000e+13  ...   95000000.0       98    590.54
# 7574   7575         ศ3-14-1/35ฉช  2.400000e+11  ...    3950000.0        3    188.70
# ...

# %% [markdown]
# ### Bar Chart

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
chonburi = data_chonburi[data_chonburi['จังหวัด']=='ชลบุรี']
chonburi =chonburi.iloc[:,1].count()
chonburi
# Out:
# 3799

# %%
rayong = data_rayong[data_rayong['จังหวัด']=='ระยอง']
rayong =rayong.iloc[:,1].count()
rayong
# Out:
# 2217

# %%
chachoengsao = data_chachoengsao[data_chachoengsao['จังหวัด']=='ฉะเชิงเทรา']
chachoengsao =chachoengsao.iloc[:,1].count()
chachoengsao
# Out:
# 1566

# %%
chonburi = data_chonburi[data_chonburi['จังหวัด']=='ชลบุรี'].count()
rayong = data_rayong[data_rayong['จังหวัด']=='ระยอง'].count()
chachoengsao = data_chachoengsao[data_chachoengsao['จังหวัด']=='ชลบุรี'].count()

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
# !ls
# Out:
# drive  sample_data  thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
labels = ['ชลบุรี','ระยอง','ฉะเชิงเทรา']
data =[chonburi,rayong,chachoengsao]
plt.bar(labels,data)
plt.ylabel('จำนวนโรงงาน')
plt.title('จังหวัดที่ตั้งโรงงาน')
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %%
chonburi = data_chonburi[data_chonburi['จังหวัด']=='ชลบุรี'].count()

# %%
chonburi
# Out:
# ลำดับ             3799
# เลขทะเบียนเดิม    3799
# FID               3799
# ชื่อโรงงาน        3799
# ประกอบกิจการ      3799
# เลขที่            3799
# หมู่              3799
# ซอย               3799
# ถนน               3799
# ตำบล              3799
# อำเภอ             3799
# จังหวัด           3799
# ไปรษณีย์          3799
# โทรศัพท์          3799
# เงินทุนรวม        3799
# คนงานรวม          3799
# แรงม้า            3799
# dtype: int64

# %%
labels = ['Chonburi','Rayong','Chachoengsao']
plt.bar(labels,rakna)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9695e10a1c0d> in <module>()
#       1 labels = ['Chonburi','Rayong','Chachoengsao']
# ----> 2 plt.bar(labels,rakna)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
plt.bar('Chonburi',chonburi);

# %%
plt.bar('Rayong',rayong);

# %%
chachoengsao

# %%
plt.bar('Chachoengsao',chachoengsao);
