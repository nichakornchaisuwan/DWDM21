# %% [markdown]
# <a href="https://colab.research.google.com/github/nichakornchaisuwan/DWDM21/blob/main/Chapter6_Association_Rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/DWDM21_DATA'

# %%
data = pd.read_csv(os.path.join(path,'reduced_marketbasket.csv'),encoding='latin1')
data
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# [Q] มีประเทศสาขาของ supermarket นี้ทั้งหมดกี่ประเทศ

# %%
set(data['Country'])
# Out:
# {'Australia',
#  'Austria',
#  'Bahrain',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Channel Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'EIRE',
#  'European Community',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Lebanon',
#  'Lithuania',
#  'Malta',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'RSA',
#  'Saudi Arabia',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'USA',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Unspecified'}

# %%
len(set(data['Country']))
# Out:
# 38

# %% [markdown]
# [HW13] วาดกราฟสรุปจำนวน items และ ยอดขายของแต่ละประเทศ

# %%
data01 = data.groupby('Country').sum().sort_values('Quantity')
data01
# Out:
#                       Quantity     UnitPrice    CustomerID
# Country
# Saudi Arabia                75  2.411000e+01  1.256500e+05
# Bahrain                    260  8.657000e+01  2.100270e+05
# RSA                        352  2.481000e+02  7.218680e+05
# Brazil                     356  1.426000e+02  4.086080e+05
# Lebanon                    386  2.424400e+02  5.743800e+05
# European Community         497  2.940500e+02  9.215880e+05
# Czech Republic             592  8.815000e+01  3.834300e+05
# Lithuania                  652  9.944000e+01  5.366200e+05
# Malta                      944  6.660100e+02  2.158496e+06
# United Arab Emirates       982  2.298900e+02  1.018952e+06
# USA                       1034  6.449800e+02  3.672086e+06
# Greece                    1556  7.132900e+02  2.008584e+06
# Iceland                   2458  4.812100e+02  2.247154e+06
# Canada                    2763  9.105800e+02  2.615483e+06
# Unspecified               3300  1.204010e+03  3.348046e+06
# ...

# %%
data02 = (data01['Quantity'])*(data01['UnitPrice'])
data02
# Out:
# Country
# Saudi Arabia            1.808250e+03
# Bahrain                 2.250820e+04
# RSA                     8.733120e+04
# Brazil                  5.076560e+04
# Lebanon                 9.358184e+04
# European Community      1.461428e+05
# Czech Republic          5.218480e+04
# Lithuania               6.483488e+04
# Malta                   6.287134e+05
# United Arab Emirates    2.257520e+05
# USA                     6.669093e+05
# Greece                  1.109879e+06
# Iceland                 1.182814e+06
# Canada                  2.515933e+06
# Unspecified             3.973233e+06
# Poland                  5.195552e+06
# Israel                  4.697061e+06
# Hong Kong               5.837971e+07
# Austria                 8.213237e+06
# Singapore               1.314199e+08
# Cyprus                  2.476308e+07
# Italy                   3.103124e+07
# Denmark                 1.037379e+07
# Channel Islands         3.543772e+07
# Finland                 4.039054e+07
# ...

# %%
datasales = pd.DataFrame(data02, columns = ['Sales'])
datasales
# Out:
#                              Sales
# Country
# Saudi Arabia          1.808250e+03
# Bahrain               2.250820e+04
# RSA                   8.733120e+04
# Brazil                5.076560e+04
# Lebanon               9.358184e+04
# European Community    1.461428e+05
# Czech Republic        5.218480e+04
# Lithuania             6.483488e+04
# Malta                 6.287134e+05
# United Arab Emirates  2.257520e+05
# USA                   6.669093e+05
# Greece                1.109879e+06
# Iceland               1.182814e+06
# Canada                2.515933e+06
# Unspecified           3.973233e+06
# Poland                5.195552e+06
# Israel                4.697061e+06
# Hong Kong             5.837971e+07
# Austria               8.213237e+06
# Singapore             1.314199e+08
# Cyprus                2.476308e+07
# Italy                 3.103124e+07
# Denmark               1.037379e+07
# Channel Islands       3.543772e+07
# Finland               4.039054e+07
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
